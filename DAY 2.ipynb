# %% [markdown]
# valid identifiers

# %%
var1 = 10
_variable = 20
var2 = 40

# %% [markdown]
# invalid variable

# %%
1var = 30
class = 40
# Out:
#   File "<ipython-input-6-0dd10858aecb>", line 1
#     1var = 30
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# variable declaration

# %%
x = 5
name = "Kanak"
pi = 3.14
print(type(x))
print(type(name))
print(type(pi))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# sequence data

# %%
my_list = [1,2,3]
my_tuple = (1,2,3)
my_range = range(5)

# %% [markdown]
# Mapping data type

# %%
details = {"name":"Kanak","age": 20}

# %% [markdown]
# Set types

# %%
my_set = {1,2,3}
my_frozenset = frozenset([1,2,3])

# %% [markdown]
# None type

# %%
nothing = None

# %% [markdown]
# implicit type

# %%
x = 5
y = 2.5
z = x + y
print(z)
# Out:
# 7.5

# %% [markdown]
# explicit type

# %%
x = "10"
y = int(x)+5
print(y)
# Out:
# 15

# %% [markdown]
# using is and is not

# %%
x = [1,2,3]
y = [1,2,3]
z = x
print(x is z)
print(x is y)
print(x is not y)
# Out:
# True
# False
# True

# %% [markdown]
# using in and not in with strings

# %%
text = "Hello, world!"
print("Hello" in text)
print("Python" not in text)
# Out:
# True
# True

# %% [markdown]
# using in and not in with lists

# %%
fruits = ["Kiwi", "Blueberry", "Custardapple"]
print("Kiwi" in fruits)
print("Cherry" not in fruits)
# Out:
# True
# True

# %% [markdown]
# Write a program for addition of float three numbers

# %%
import math
a = float(input("Enter first number:"))
b = float(input("Enter second number:"))
c = float(input("Enter third number:"))
addition = a + b + c
print("Sum of first number,second number,third number", addition)
# Out:
# Enter first number:10
# Enter second number:20
# Enter third number:30
# Sum of first number,second number,third number 60.0

# %% [markdown]
# write a program to find area of rhombus

# %%
a = float(input("Enter the base:"))
b = float(input("Enter the height:"))
area = a * b
print("Area of the rhombus",area)
# Out:
# Enter the base:20
# Enter the height:40
# Area of the rhombus 800.0

# %% [markdown]
# Write a program of area of parallelogram

# %%
a = float(input("Enter the Base:"))
b = float(input("Enter the Height:"))
area = a * b
print("Area of the Parallelogram", area)
# Out:
# Enter the Base:5
# Enter the Height:10
# Area of the Parallelogram 50.0

# %% [markdown]
# Write a program to find the volume and surface area of cube

# %%
import math
s = float(input("Enter the volume of a cube:"))
s = float(input("Enter the surface area of the cube:"))
volume = s*s*s
surface_area = 6 * (s**2)
print("volume of a cube",volume)
print("surface area of the cube",surface_area)
# Out:
# Enter the volume of a cube:2
# Enter the surface area of the cube:2
# volume of a cube 8.0
# surface area of the cube 24.0

# %% [markdown]
# using in with dictionaries

# %%
my_dict = {"name": "Alice", "age": 25}
print("name" in my_dict)
print("Alice" in my_dict)
# Out:
# True
# False

# %% [markdown]
# left-to-right associativity

# %%
result = 10 - 5 + 2
print(result)
# Out:
# 7

# %% [markdown]
# Right-to-left associativity

# %%
result = 2**3**2
print(result)
# Out:
# 512

# %% [markdown]
# Clarity without Parenthese

# %%
result = 3 + 5 * 2 - 8 / 4
print(result)
# Out:
# 11.0

# %% [markdown]
# with parenthese

# %%
result = (3 + (5 * 2)) - (8 / 4)
print(result)
# Out:
# 11.0

# %%
result = 10 + 2 * 3 ** 2
print(result)
# Out:
# 28

# %%
result = 4 + 8 / 2**2*3
print(result)
# Out:
# 10.0

# %% [markdown]
# write a program using bitwise operator

# %%
x = 5
y = 7
print(f"Before swapping: x = {x}, y = {y}")
#swapping using xor
x = x^y
y = x^y
x = x^y
print(f"After swapping: x = {x}, y = {y}")
# Out:
# Before swapping: x = 5, y = 7
# After swapping: x = 7, y = 5
