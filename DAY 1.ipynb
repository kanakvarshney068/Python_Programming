# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
def add(a,b):
  return a + b
  print(add(2,3))

# %%
a = 5
b = 10
print(a + b)
# Out:
# 15

# %% [markdown]
# Printing string

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Printing variables

# %%
name = "Kanak"
age = 20
print(name)
print(age)
# Out:
# Kanak
# 20

# %% [markdown]
# Printing Multiple values

# %%
name = "Kanak"
age = 20
print("Name:", name, "Age:",age)
# Out:
# Name: Kanak Age: 20

# %% [markdown]
# using f-strings

# %%
name = "Kanak"
age = 20
print(f"Name: {name},Age:{age}")
# Out:
# Name: Kanak,Age:20

# %% [markdown]
# using.format() Method

# %%
name = "Kanak"
age = 20
print("Name:{}, Age:{}".format(name,age))
# Out:
# Name:Kanak, Age:20

# %% [markdown]
# Printing Formatted Numbers

# %%
number = 1234567890.0987654321
print(f"Formatted Number:{number:.5f}")
# Out:
# Formatted Number:1234567890.09877

# %% [markdown]
# using string concatenation

# %%
name = "Alice"
print("Hello, " + name +"!")
# Out:
# Hello, Alice!

# %% [markdown]
# using sep Parameter

# %%
print("Kiwi","Blueberry", sep="-")
print("NIET","Greater","Noida", sep="-")
# Out:
# Kiwi-Blueberry
# NIET-Greater-Noida

# %% [markdown]
# using end Parameter

# %%
print("Hello", end=",")
print("World!")
# Out:
# Hello,World!

# %% [markdown]
# Printing Escape Sequences

# %%
print("Kanak\nBiotech")
# Out:
# Kanak
# Biotech

# %% [markdown]
# Printing Raw strings

# %%
print(r"path:C:\users\Kanak\Documents")
# Out:
# path:C:\users\Kanak\Documents

# %% [markdown]
# Program to Add Two Numbers

# %%
num1 = float(input("Enter the first number:"))
num2 = float(input("Enter the second number:"))
addition = num1 + num2
print("Addition:", addition)
# Out:
# Enter the first number:20
# Enter the second number:40
# Addition: 60.0

# %% [markdown]
# program to swap two numbers using a temporaray variable

# %%
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))

#swapping using a temporary variable
temp = a
a = b
b = temp

#Displaying swapped values
print("After swapping:")
print("First number:", a)
print("Second number:", b)
# Out:
# Enter the first number:45
# Enter the second number:60
# After swapping:
# First number: 60
# Second number: 45

# %% [markdown]
# Program to swap two numbers without using a third variable

# %%
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))

#swapping without using a third variable
a = a + b
b = a - b
a = a - b

#Displaying swapped values
print("After swapping:")
print("First number:", a)
print("second number:", b)
# Out:
# Enter the first number:45
# Enter the second number:89
# After swapping:
# First number: 89
# second number: 45

# %% [markdown]
# Program to calculate the perimeter and area of a triangle

# %%
import math
a = float(input("Enter the first side of the triangle:"))
b = float(input("Enter the second side of the triangle:"))
c = float(input("Enter the third side of the triangle:"))
perimeter = a+b+c
print("Perimeter of the triangle:", perimeter)
s = perimeter/2
area = math.sqrt(s*(s-a)*(s-b)*(s-c))
print("Area of the triangle:", area)
# Out:
# Enter the first side of the triangle:90
# Enter the second side of the triangle:80
# Enter the third side of the triangle:70
# Perimeter of the triangle: 240.0
# Area of the triangle: 2683.281572999748

# %% [markdown]
# Program to convert Fahreheit to celsius

# %%
f = float(input("Enter temperature in fahrenheit:"))
c = (f - 32)*5/9
print(f"{f}F is equal to{c:.2f}C")
# Out:
# Enter temperature in fahrenheit:5
# 5.0F is equal to-15.00C

# %% [markdown]
# Program to calculate Simple Interest

# %%
principal = float(input("Enter the principal amount:"))
rate = float(input("Enter the rate of interest (in %):"))
time = float(input("Enter the time (in years):"))
simple_interest = (principal * rate * time ) / 100
print("The simple interest is:", simple_interest)
# Out:
# Enter the principal amount:34
# Enter the rate of interest (in %):45
# Enter the time (in years):56
# The simple interest is: 856.8

# %% [markdown]
# Program to calculate the Surface area of a Cylinder

# %%
import math
r = float(input("Enter the radius of the cylinder:"))
h = float(input("Enter the height of the cylinder:"))
surface_area = 2*math.pi * r * (r + h)
print("The surface area of the cylinder is:", surface_area)
# Out:
# Enter the radius of the cylinder:25
# Enter the height of the cylinder:100
# The surface area of the cylinder is: 19634.95408493621

# %% [markdown]
# Program to calculate the Hypotenuse of a right-angled triangle

# %%
import math
side1 = float(input("Enter the first side of the triangle:"))
side2 = float(input("Enter the second side of the triangle:"))
h = math.sqrt(side1**2 + side2**2)
print("The hypotenuse of the triangle is:", h)
# Out:
# Enter the first side of the triangle:80
# Enter the second side of the triangle:70
# The hypotenuse of the triangle is: 106.30145812734649

# %% [markdown]
# Program to calculate compound interest

# %%
principal = float(input("Enter the principal amount:"))
rate = float(input("Enter the annual rate of interest(in %):"))
time = float(input("Enter the time (in years):"))
compound_interest = principal * (1 + rate/100)**time - principal
print("The compound interest is:", compound_interest)
# Out:
# Enter the principal amount:80
# Enter the annual rate of interest(in %):90
# Enter the time (in years):70
# The compound interest is: 2.605205903849561e+21
