# %% [markdown]
# Packing

# %%
packed = 1,2,3,4
print(packed)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# Unpacking

# %%
x,y,z = 10,20,30
print(x,y,z)
# Out:
# 10 20 30

# %% [markdown]
# Using * to collect remaining items

# %%
a,*b = [1,2,3,4]
print(a,b) # *is used to assign the multiple value of b
# Out:
# 1 [2, 3, 4]

# %%
*a,b = [1,2,3,4] #*is used to assign the multiple value of a
print(a,b)
# Out:
# [1, 2, 3] 4

# %%
def return_multiple():
  return 5, 10, 15
val1, val2, val3 = return_multiple()
print(val1, val2, val3)
# Out:
# 5 10 15

# %%
my_list = [1,2,3]
my_list[1]= 20
print(my_list)
# Out:
# [1, 20, 3]

# %%
text = "hello"
text[0] = "H"
print(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-bb72f5ff148e> in <cell line: 0>()
#       1 text = "hello"
# ----> 2 text[0] = "H"
#       3 print(text)
#
# TypeError: 'str' object does not support item assignment

# %%
my_tuple = (1,2,3)
my_tuple[1] = 20
print(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-8c12d143dad4> in <cell line: 0>()
#       1 my_tuple = (1,2,3)
# ----> 2 my_tuple[1] = 20
#       3 print(my_tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
"hello".find("e")
# Out:
# 1

# %%
"hello".find("h")
# Out:
# 0

# %%
"hello".replace("l","x")
# Out:
# 'hexxo'

# %%
"42".zfill(5)
# Out:
# '00042'

# %%
"hello".center(50)
# Out:
# '                      hello                       '

# %%
"hello".ljust(10)
# Out:
# 'hello     '

# %%
name = "Alice"
age = 25
print(f"Name: {name}, Age: {age}")
# Out:
# Name: Alice, Age: 25

# %% [markdown]
# append(x)

# %%
lst = [1,2];
lst.append(3)
print(lst)
# Out:
# [1, 2, 3]

# %% [markdown]
# extend(iterable)

# %%
lst = [1,2];
lst.extend([3,4])
print(lst)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# insert(i,x)

# %%
lst = [1,2];
lst.insert(1,99)
print(lst)
# Out:
# [1, 99, 2]

# %%
lst = [1,2];
lst.insert(2,99)
print(lst)
# Out:
# [1, 2, 99]

# %% [markdown]
# clear()

# %%
lst = [1,2,3];
lst.clear()
print(lst)
# Out:
# []

# %% [markdown]
# index(x[start,end])

# %%
lst = [1,2,3];
lst.index(2)
# Out:
# 1

# %% [markdown]
# count(x)

# %%
lst = [1,2,3,3,3];
lst.count(3)
# Out:
# 3

# %% [markdown]
# sort(key = None, reverse = False)

# %%
lst = [3,2,1];
lst.sort()
print(lst)
# Out:
# [1, 2, 3]

# %% [markdown]
# reverse()

# %%
lst = [1,2,3];
lst.reverse()
print(lst)
# Out:
# [3, 2, 1]

# %% [markdown]
# copy()

# %%
lst = [1,2];
new_lst = lst.copy()
print(new_lst)
# Out:
# [1, 2]

# %% [markdown]
# syntax:

# %%
squares = [x**2 for x in range(1,6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
# Filter even numbers
evens = [x for x in range(10) if x%2 == 0]
print(evens)
# Out:
# [0, 2, 4, 6, 8]

# %%
my_tuple = (10,20,30,10)
print(my_tuple.count(10))
print(my_tuple.index(20))
# Out:
# 2
# 1

# %% [markdown]
# Tuple Packing and Unpacking

# %%
packed = 1,2,3
x,y,z = packed
print(x,y,z)
# Out:
# 1 2 3

# %% [markdown]
# Write a function that returns the sum and product of two numbers.Use unpacking to assign the results

# %%
def sum_and_product(a,b):
  return a + b,a*b
result_sum,result_product = sum_and_product(4,5)
print(result_sum,result_product)
# Out:
# 9 20

# %% [markdown]
# Create a list of squares for all odd numbers between 1 and 10

# %%
odd_squares = [x**2 for x in range(1,11) if x%2 != 0]
print(odd_squares)
# Out:
# [1, 9, 25, 49, 81]

# %%
my_tuple = (10,20,30,40)
print(my_tuple.count(20))
print(my_tuple.index(30))
# Out:
# 1
# 2

# %% [markdown]
# Write a program to count the number of vowels in a given string

# %%
text = "Hello,Python!"
vowels = [char for char in text if char.lower() in 'aeiou']
print(len(vowels))
# Out:
# 3

# %%
#Generate random numbers within a range
import random
def generate_random_numbers(start, end, count):
  return [random.randint(start,end) for _ in range(count)]
random_numbers = generate_random_numbers(1,100,5)
print(random_numbers)
# Out:
# [32, 79, 44, 29, 76]
