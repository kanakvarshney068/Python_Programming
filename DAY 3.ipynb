# %% [markdown]
# Constant expression

# %%
result = 10 + 20
print(result)
# Out:
# 30

# %% [markdown]
# Arithmetic expression

# %%
a = 15
b = 5
result = (a + b) *2
print(result)
# Out:
# 40

# %% [markdown]
# Logical expression

# %%
is_valid = True
is_complete = False
print(is_valid and not is_complete)
# Out:
# True

# %% [markdown]
# Bitwise expression

# %%
x = 5
y = 3
print(x & y)
# Out:
# 1

# %% [markdown]
# Relational expression

# %%
a = 10
b = 20
print(a<b)
# Out:
# True

# %% [markdown]
# String expression

# %%
greeting = "Hello" + "World"
print(greeting)
# Out:
# HelloWorld

# %%
#single-quoted string
greeting = 'Hello'

# %%
#Double-quoted string
name = "Alice"

# %%
#Triple-quoted string
multiline_text = '''This is a multi-line string'''
print(greeting)
print(name)
print(multiline_text)
# Out:
# Hello
# Alice
# This is a multi-line string

# %% [markdown]
# String indexing

# %%
Text = "Python"
#Forward indexing
print(Text[0])
print(Text[3])
#Reverse indexing
print(Text[-1])
print(Text[-3])
# Out:
# P
# h
# n
# h

# %%
text = "Python Programming"
#basic slicing
print(text[0:6])
print(text[:6])
print(text[7:])
#Using step
print(text[0:12:2])
#Reverse slicing
print(text[::-1])
# Out:
# Python
# Python
# Programming
# Pto rg
# gnimmargorP nohtyP

# %% [markdown]
# Using format() method

# %%
name = "Kanak"
age = 20
print("My name is {} and I am {} years old.".format(name,age))
# Out:
# My name is Kanak and I am 20 years old.

# %% [markdown]
# Using f-strings

# %%
name = "Bob"
age = 30
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Bob and I am 30 years old.

# %% [markdown]
# Using % operator(old method)

# %%
name = "Eve"
age = 22
print("My name is %s and I am %d years old." %(name,age))
# Out:
# My name is Eve and I am 22 years old.

# %% [markdown]
# Basic operator
# concatenation

# %%
str1 = "Hello"
str2 = "World"
result = str1 + "" + str2
print(result)
# Out:
# HelloWorld

# %% [markdown]
# Repetition method

# %%
text = "Python"
print(text * 3)
# Out:
# PythonPythonPython

# %% [markdown]
# Membership Method

# %%
text = "Python Programming"
print("Python" in text)
print("Java" not in text)
# Out:
# True
# True

# %% [markdown]
# Common String Methods

# %%
text = "Hello   Python"

print(text.lower())
print(text.upper())
print(text.strip())

words = (text.split())
print(words)

joined = "-".join(words)
print(joined)

print(text.replace("Python", "World"))

print(text.find("Python"))
print(text.startswith("Hello"))
print(text.endswith("Python"))
# Out:
# hello   python
# HELLO   PYTHON
# Hello   Python
# ['Hello', 'Python']
# Hello-Python
# Hello   World
# 8
# True
# True

# %%
#Creating a list
my_list = [1,2,3,"Hello", 4.5]
print(my_list)
# Out:
# [1, 2, 3, 'Hello', 4.5]

# %%
#Creating a tuple
my_tuple = (1,2,3,"Hello", 4.5)
print(my_tuple)
# Out:
# (1, 2, 3, 'Hello', 4.5)

# %%
#Creating a set
my_set = {1,2,3,4}
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
#Creating a dictionary
my_dict = {"name": "Alice", "age": 25, "city": "New York" }
print(my_dict)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %% [markdown]
# ⏰**PRACTICE QUESTION:**

# %% [markdown]
# Convert a string to uppercase and lowercase

# %%
text = "Python Programming"
print(text.upper())
print(text.lower())
# Out:
# PYTHON PROGRAMMING
# python programming

# %% [markdown]
# Find the number of occurrences of a  substring

# %%
text = "Custard apple"
print(text.count("p"))
# Out:
# 2

# %% [markdown]
# Check if a string starts and ends with a specific substring

# %%
text = "Hello,Python!"
print(text.startswith("Hello,"))
print(text.endswith("Python!"))
# Out:
# True
# True

# %% [markdown]
# Extracting initials from a full name

# %%
def get_initails(full_name):
  names = full_name.split()
  initails = "".join([name[0].upper() for name in names])
  return initails
name = "Kanak Varshney"
print(get_initails(name))
# Out:
# KV

# %% [markdown]
# Count vowels in a string

# %%
def count_vowels(text):
  vowels = "aeiouAEIOU"
  return sum(1 for char in text if char in vowels)
sentence = "Python is fun"
print(count_vowels(sentence))
# Out:
# 3

# %% [markdown]
# Reverse words in a sentence

# %%
def reverse_words(sentence):
  words = sentence.split()
  reversed_sentence = "".join(reversed(words))
  return reversed_sentence
text = "Python is fun"
print(reverse_words(text))
# Out:
# funisPython

# %% [markdown]
# Replace spaces with hyphens in a string

# %%
text = "python is amazing"
print(text.replace("","-"))
# Out:
# -p-y-t-h-o-n- -i-s- -a-m-a-z-i-n-g-

# %% [markdown]
# Check if a string is a palindrome.

# %%
def is_palindrome(text):
  text = text.replace("","").lower()
  return text == text[::-1]

word = "madam"
print(is_palindrome(word))
# Out:
# True
